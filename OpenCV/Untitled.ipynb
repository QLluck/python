# %%
import cv2
print("OpenCV 版本:", cv2.__version__)
# Out:
# OpenCV 版本: 4.10.0

# %%
srcImg = cv2.imread("截屏2024-11-01 07.52.57.png",0)
print(srcImg)
# Out:
# [[  0   0   0 ...   0   0   0]
#  [ 46  46  46 ... 105 106 106]
#  [ 46  46  46 ... 105 106 106]
#  ...
#  [ 30  32  35 ...  14  14  13]
#  [ 31  33  33 ...  13  13  14]
#  [ 30  32  30 ...  12  11  11]]

# %%
shape = srcImg.shape
height = shape[0]
width = shape[1]
ndim = srcImg.ndim
if srcImg.ndim == 2:
    channels = 1
elif srcImg.ndim == 3:
    channels = shape[-1]

# %%
shape
# Out:
# (1662, 3352)

# %%
height
# Out:
# 1662

# %%
ndim
# Out:
# 2
